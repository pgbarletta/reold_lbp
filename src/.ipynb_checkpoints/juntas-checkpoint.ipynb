# %%
using DataFrames
using Gadfly
set_default_plot_size(30cm, 12cm)
home = "/home/german/labo/18/lbp/run"
rtdos = "/home/german/labo/18/lbp/rtdos_log"
# Out:
# "/home/german/labo/18/lbp/rtdos_log"

# %%
function get_κ(in_vec::Array{Float64, 1})
    not_null = copy(in_vec)
    not_null[not_null .== 0] = 0.000001
    const κ = (exp.(-mapslices(x -> sum(x), mapslices(x->x.^2 .* log.(x.^2), not_null, 1), 1))
        / length(not_null))[1]
    return κ
end

function get_pnum(in_vec::Array{Float64, 1})
    nor_vec = in_vec ./ norm(in_vec) 
    return convert(Int64, round(sum(nor_vec .^ 4) .^ -1))
end

function tognm(vtor_anm)
    vtor_gnm = Array{Float64}
    try
        vtor_gnm = Array{Float64}(convert(Int64, length(vtor_anm)/3));
    catch e
        warn("Input vector's length is not a 3 multiplier")
        error(e)
    end
    vtor_anm =  vtor_anm.^2
    for i=1:convert(Int64, length(vtor_anm)/3)
        vtor_gnm[i] = sqrt(vtor_anm[i*3-2] + vtor_anm[i*3-1] + vtor_anm[i*3])
    end
    return vtor_gnm
end

function WeightedHist(in_vec, in_bins, in_weight, density = false)
    # Safety check    
    if length(in_vec) != length(in_weight)
        error("Each element of the input vector needs one weight")
        return
    end
    
    # Prepare variables
    out_counts = Array{Float64}(length(in_bins)-1)
    
    # Get weighted histogram
    for i=1:length(in_bins)-1
        if i == 1
            # Include those that fall before the beggining of the bins
            temp_bool = (in_vec .>= in_bins[i]) .& (in_vec .< in_bins[i+1]) .| (in_vec .<= in_bins[i])
            out_counts[i] = sum(in_weight[temp_bool])
        elseif i == length(in_bins)-1
            # Include those that fall after the end of the bins
            temp_bool = (in_vec .>= in_bins[i]) .& (in_vec .< in_bins[i+1]) .| (in_vec .>= in_bins[end])
            out_counts[i] = sum(in_weight[temp_bool])
        else
            temp_bool = (in_vec .>= in_bins[i]) .& (in_vec .< in_bins[i+1])
            out_counts[i] = sum(in_weight[temp_bool])
        end
    end
    
    # Get bins middle points
    out_middle = (in_bins[1:end-1] + in_bins[2:end]) / 2
    
    # Turn counts into density
    if (density == true)
        out_counts = out_counts ./ sum(out_counts) 
    end
    return out_counts, out_middle
end

function read_ptraj_modes(filename, nmodes::Int64=0, norma::Bool=true)
    modes_text = readdlm(filename, skipstart=0, skipblanks=true, comments=true,
        comment_char='\*')

    if nmodes == 0
        nmodes = modes_text[1, 5]
    end
    modes_elements = modes_text[2, 1]

    ncoords = convert(Int64, modes_elements)
    lines = ceil(Int64, ncoords/7)
    rest = convert(Int64, ncoords % 7)

    eval = Array{Float64}(nmodes);
    mode = Array{Float64}(ncoords, nmodes);
    temp1 = Array{Float64}(ncoords, 1);
    temp2 = Array{Float64}(ncoords+(7-rest));

    j=lines + 1 + 2 # 1 p/ q lea la prox linea 2 por el header
    for i=1:nmodes
        eval[i] = modes_text[j, 2]
        temp = permutedims(modes_text[(j+1):(lines+j), :], [2, 1])
        temp2 = reshape(temp, ncoords+(7-rest))
        for k=(rest+1):7
            pop!(temp2)
        end
        mode[:, i] = temp2
        j = j + lines + 1
    end

    if norma == true
        for i=1:nmodes
            mode[: ,i] = mode[:, i] / norm(mode[:, i])
        end
    end

    return mode, eval
end
# Out:
# read_ptraj_modes (generic function with 3 methods)

# %% [markdown]
# ## RMSF

# %%
pdb = "1ael"
rmsf_1ael = readdlm(joinpath(home, pdb, "rmsf", string("rmsf_", pdb)))[:, 2]

pdb = "1ure"
rmsf_1ure = readdlm(joinpath(home, pdb, "rmsf", string("rmsf_", pdb)))[:, 2]

pdb = "4uet"
rmsf_4uet = readdlm(joinpath(home, pdb, "rmsf", string("rmsf_", pdb)))[:, 2]

pdb = "4xcp"
rmsf_4xcp = readdlm(joinpath(home, pdb, "rmsf", string("rmsf_", pdb)))[:, 2]

aa_alfa = length(ca_indices_4uet)
aa_beta = length(ca_indices_1ael)
start_alfa = 10
start_beta = 7

ca_idx_1ael = collect(start_beta:aa_beta+start_beta - 1)
ca_idx_1ure = collect(start_beta:aa_beta+start_beta - 1)
ca_idx_4uet = collect(start_alfa:aa_alfa+start_alfa - 1)
ca_idx_4xcp = collect(start_alfa:aa_alfa+start_alfa - 1);

# %%
df_rmsf = DataFrame(RMSF = [ rmsf_1ael ; rmsf_1ure ; rmsf_4uet ; rmsf_4xcp ],
    Calpha = [ ca_idx_1ael ; ca_idx_1ure ; ca_idx_4uet ; ca_idx_4xcp ],
    Protein = [ fill("1AEL", length(rmsf_1ael)) ; fill("1URE", length(rmsf_1ure)) ;
        fill("4UET", length(rmsf_4uet)) ; fill("4XCP", length(rmsf_4xcp)) ]);

df_rmsf_alfa = DataFrame(RMSF = [ rmsf_4uet ; rmsf_4xcp ],
    Calpha = [ ca_idx_4uet ; ca_idx_4xcp ],
    Protein = [ fill("4UET", length(rmsf_4uet)) ; fill("4XCP", length(rmsf_4xcp)) ]);

df_rmsf_beta = DataFrame(RMSF = [ rmsf_1ael ; rmsf_1ure ],
    Calpha = [ ca_idx_1ael ; ca_idx_1ure ],
    Protein = [ fill("1AEL", length(rmsf_1ael)) ; fill("1URE", length(rmsf_1ure)) ]);

# %%
pdf_rmsf = plot(df_rmsf, x = "Calpha", y = "RMSF", color = "Protein",
    Geom.line,
    #Guide.title("Cut"),
    Coord.cartesian(xmin = 10, xmax = 144, ymin = .6, ymax = 6),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_rmsf_alfa = plot(df_rmsf_alfa, x = "Calpha", y = "RMSF", color = "Protein",
    Geom.line,
    #Guide.title("Cut"),
    Coord.cartesian(xmin = 10, xmax = 144, ymin = .6, ymax = 4),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_rmsf_beta = plot(df_rmsf_beta, x = "Calpha", y = "RMSF", color = "Protein",
    Geom.line,
    #Guide.title("Cut"),
    Coord.cartesian(xmin = 7, xmax = 126, ymin = .4, ymax = 6),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %% [markdown]
# ## Frecuencia

# %%
# Frecuencias
df_Whis_evals_1ael = readtable(joinpath(rtdos, "freq_hist_1ael"), separator = '\t')
df_Whis_evals_1ure = readtable(joinpath(rtdos, "freq_hist_1ure"), separator = '\t')
df_Whis_evals_4uet = readtable(joinpath(rtdos, "freq_hist_4uet"), separator = '\t')
df_Whis_evals_4xcp = readtable(joinpath(rtdos, "freq_hist_4xcp"), separator = '\t');

df_evals = DataFrame(Probability = [ df_Whis_evals_1ael[:, 1] ; df_Whis_evals_1ure[:, 1] ;
        df_Whis_evals_4uet[:, 1] ; df_Whis_evals_4xcp[:, 1] ],
    Volume = repeat(df_Whis_evals_1ael[:, 2], outer = 4),
    Protein = repeat(["1AEL" ; "1URE" ; "4UET" ; "4XCP"], inner = length(df_Whis_evals_1ure[:, 1])));

df_evals_alfa = DataFrame(Probability = [ df_Whis_evals_4uet[:, 1] ; df_Whis_evals_4xcp[:, 1] ],
    Volume = repeat(df_Whis_evals_1ael[:, 2], outer = 2),
    Protein = repeat(["4UET" ; "4XCP"], inner = length(df_Whis_evals_1ure[:, 1])));

df_evals_beta = DataFrame(Probability = [ df_Whis_evals_1ael[:, 1] ; df_Whis_evals_1ure[:, 1] ],
    Volume = repeat(df_Whis_evals_1ael[:, 2], outer = 2),
    Protein = repeat(["1AEL" ; "1URE" ], inner = length(df_Whis_evals_1ure[:, 1])));

# %%
pdf_evals = plot(df_evals, x = "Volume", y = "Probability", color = "Protein",
    Geom.bar(position=:dodge),
    #Guide.title("Cut"),
    #Coord.cartesian(xmin = 400, xmax = 1600, ymax = 0.3),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_evals_alfa = plot(df_evals_alfa, x = "Volume", y = "Probability", color = "Protein",
    Geom.bar(position=:dodge),
    #Guide.title("Cut"),
    #Coord.cartesian(xmin = 400, xmax = 1600, ymax = 0.3),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_evals_beta = plot(df_evals_beta, x = "Volume", y = "Probability", color = "Protein",
    Geom.bar(position=:dodge),
    #Guide.title("Cut"),
    #Coord.cartesian(xmin = 400, xmax = 1600, ymax = 0.3),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %% [markdown]
# ## VGV cartesiano

# %%
# VGV cartesiano
car_vgv_1ael = readdlm(joinpath(rtdos, "car_vgv_1ael"))[:, 1]
car_vgv_1ure = readdlm(joinpath(rtdos, "car_vgv_1ure"))[:, 1]
car_vgv_4uet = readdlm(joinpath(rtdos, "car_vgv_4uet"))[:, 1]
car_vgv_4xcp = readdlm(joinpath(rtdos, "car_vgv_4xcp"))[:, 1];

# 1AEL
tmp = abs.(tognm(car_vgv_1ael))
tmp_ = copy(tmp)
tmp_[tmp_ .< .13] .= 0.

layer_1ael_1 = layer(DataFrame(Displacement = tmp), Geom.bar, y = "Displacement")
layer_1ael_2 = layer(DataFrame(Displacement = tmp_), Geom.bar, y = "Displacement",
Theme(default_color=colorant"crimson", bar_spacing=2pt));

# 1URE
tmp = abs.(tognm(car_vgv_1ure))
tmp_ = copy(tmp)
tmp_[tmp_ .< .13] .= 0.

layer_1ure_1 = layer(DataFrame(Displacement = tmp), Geom.bar, y = "Displacement")
layer_1ure_2 = layer(DataFrame(Displacement = tmp_), Geom.bar, y = "Displacement",
Theme(default_color=colorant"crimson", bar_spacing=2pt));

# 4UET
tmp = abs.(tognm(car_vgv_4uet))
tmp_ = copy(tmp)
tmp_[tmp_ .< .13] .= 0.

layer_4uet_1 = layer(DataFrame(Displacement = tmp), Geom.bar, y = "Displacement")
layer_4uet_2 = layer(DataFrame(Displacement = tmp_), Geom.bar, y = "Displacement",
Theme(default_color=colorant"crimson", bar_spacing=2pt));

# 4XCP
tmp = abs.(tognm(car_vgv_4xcp))
tmp_ = copy(tmp)
tmp_[tmp_ .< .13] .= 0.

layer_4xcp_1 = layer(DataFrame(Displacement = tmp), Geom.bar, y = "Displacement")
layer_4xcp_2 = layer(DataFrame(Displacement = tmp_), Geom.bar, y = "Displacement",
Theme(default_color=colorant"crimson", bar_spacing=2pt));

# %%
pdf_cart_gdte = plot(layer_1ael_2, layer_1ael_1,
    Guide.xlabel("AA"),
    Guide.ylabel("Displacement"), Coord.cartesian(ymax = 0.5),
    Guide.xticks(ticks=collect(0:10:120)),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt,
        key_label_font_size = 15pt))
# Out:
# Plot(...)

# %%
pdf_cart_gdte = plot(layer_1ure_2, layer_1ure_1,
    Guide.xlabel("AA"),
    Guide.ylabel("Displacement"), Coord.cartesian(ymax = 0.5),
    Guide.xticks(ticks=collect(0:10:120)),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt,
        key_label_font_size = 15pt))
# Out:
# Plot(...)

# %%
pdf_cart_gdte = plot(layer_4uet_2, layer_4uet_1,
    Guide.xlabel("AA"),
    Guide.ylabel("Displacement"), Coord.cartesian(ymax = 0.5),
    Guide.xticks(ticks=collect(0:10:120)),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt,
        key_label_font_size = 15pt))
# Out:
# Plot(...)

# %%
pdf_cart_gdte = plot(layer_4xcp_2, layer_4xcp_1,
    Guide.xlabel("AA"),
    Guide.ylabel("Displacement"), Coord.cartesian(ymax = 0.5),
    Guide.xticks(ticks=collect(0:10:120)),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt,
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt,
        key_label_font_size = 15pt))
# Out:
# Plot(...)

# %% [markdown]
# ## Volumen de la trayectoria

# %%
# Leo histogramas de volumen
df_Whis_vol_1ael = readtable(joinpath(rtdos, "hist_vol_1ael"), separator = '\t')
df_Whis_vol_1ure = readtable(joinpath(rtdos, "hist_vol_1ure"), separator = '\t')
df_Whis_vol_4uet = readtable(joinpath(rtdos, "hist_vol_4uet"), separator = '\t')
df_Whis_vol_4xcp = readtable(joinpath(rtdos, "hist_vol_4xcp"), separator = '\t');

df_vol = DataFrame(Probability = [ df_Whis_vol_1ael[:, 1] ; df_Whis_vol_1ure[:, 1] ;
        df_Whis_vol_4uet[:, 1] ; df_Whis_vol_4xcp[:, 1] ],
    Volume = repeat(df_Whis_vol_1ael[:, 2], outer = 4),
    Protein = repeat(["1AEL" ; "1URE" ; "4UET" ; "4XCP"], inner = length(df_Whis_vol_1ure[:, 1])));

df_vol_alfa = DataFrame(Probability = [ df_Whis_vol_4uet[:, 1] ; df_Whis_vol_4xcp[:, 1] ],
    Volume = repeat(df_Whis_vol_1ael[:, 2], outer = 2),
    Protein = repeat(["4UET" ; "4XCP"], inner = length(df_Whis_vol_1ure[:, 1])));

df_vol_beta = DataFrame(Probability = [ df_Whis_vol_1ael[:, 1] ; df_Whis_vol_1ure[:, 1] ],
    Volume = repeat(df_Whis_vol_1ael[:, 2], outer = 2),
    Protein = repeat(["1AEL" ; "1URE" ], inner = length(df_Whis_vol_1ure[:, 1])));

# %%
pdf_vol = plot(df_vol, x = "Volume", y = "Probability", color = "Protein",
    Geom.bar(position=:dodge),
    #Guide.title("Cut"),
    Coord.cartesian(xmin = 400, xmax = 1600, ymax = 0.3),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_vol_alfa = plot(df_vol_alfa, x = "Volume", y = "Probability", color = "Protein",
    Geom.bar(position=:dodge),
    #Guide.title("Cut"),
    Coord.cartesian(xmin = 400, xmax = 1600, ymax = 0.301),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)

# %%
pdf_vol_beta = plot(df_vol_beta, x = "Volume", y = "Probability", color = "Protein",
    Geom.bar(position=:dodge),
    #Guide.title("Cut"),
    Coord.cartesian(xmin = 400, xmax = 1600, ymax = 0.301),
    #Guide.xlabel("Frecuency (cm<sup>-1</sup>)"), Guide.xticks(ticks=collect(0:50:775)),
    #Guide.ylabel("δV * Probability", orientation=:vertical),
    
    Theme(bar_spacing=2pt, grid_line_width=1pt, Theme(default_color=colorant"DarkBlue"),
        minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)
