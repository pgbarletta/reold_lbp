# %%
using DelimitedFiles, HDF5, FileIO
using Plots, Rsvg, LaTeXStrings, StatPlots
using Chemfiles, JUMD
using LinearAlgebra, Statistics
home = "/home/pbarletta/labo/18/lbp/run"
rtdos = "/home/pbarletta/labo/18/lbp/rtdos_log"
pyplot()
# Out:
# ┌ Info: Recompiling stale cache file /home/pbarletta/.julia/compiled/v1.0/JUMD.ji for JUMD [top-level]
# └ @ Base loading.jl:1187
# Plots.PyPlotBackend()

# %% [markdown]
# ### Lee modos, volumen original y  volúmenes NDD. Obtiene VGV

# %%
pdb = "4xcp"
# Leo modos
modes_4xcp, evals_4xcp = JUMD.readPtrajModes(
    joinpath(home, pdb,  "pca", string("full_modes_", pdb)))

# AAs
aa3 = convert(Int64, length(evals_4xcp))
aa = convert(Int64, aa3 / 3)

# Leo volumen de la traj
trj_vol = convert(Array{Float64, 1}, 
    readdlm(joinpath(home, pdb, "cavidad", string("vol_trj_", pdb)))[:, 3]);

# Leo volúmene del average
vol_avg_4xcp = convert(Float64, readdlm(joinpath(home, pdb,  "ndd", string("vol_avg_", pdb)))[3])

# Leo volúmenes NDD
ndd_out_4xcp = convert(Array{Float64, 1},
    readdlm(joinpath(home, pdb,  "ndd", string("out_ndd_", pdb)))[2:end, 2])

# VGV
vgv_4xcp = (ndd_out_4xcp .- vol_avg_4xcp) .* evals_4xcp
vgv_4xcp = vgv_4xcp ./ norm(vgv_4xcp);

# %% [markdown]
# ### Obtengo proyecciones de PCA sobre trayectoria

# %%
dif = h5read(joinpath(rtdos, string("diff_", pdb, ".h5")), "dif")
norm_dif = mapslices(x -> x ./ norm(x), dif,  dims = 1)
nframes = size(dif)[2]

prj_1_4xcp = Array{Float64, 1}(undef, nframes)
prj_2_4xcp = Array{Float64, 1}(undef, nframes)
prj_3_4xcp = Array{Float64, 1}(undef, nframes)

for i = 1:nframes
    prj_1_4xcp[i] = dot(norm_dif[:, i], modes_4xcp[:, 1])
    prj_2_4xcp[i] = dot(norm_dif[:, i], modes_4xcp[:, 2])
    prj_3_4xcp[i] = dot(norm_dif[:, i], modes_4xcp[:, 3])
end

# Smooth
smooth_prj_1_4xcp = [ mean(prj_1_4xcp[i:i+9]) for i = 1:10:length(prj_1_4xcp)-9 ]
smooth_prj_2_4xcp = [ mean(prj_2_4xcp[i:i+9]) for i = 1:10:length(prj_2_4xcp)-9 ]
smooth_prj_3_4xcp = [ mean(prj_3_4xcp[i:i+9]) for i = 1:10:length(prj_3_4xcp)-9 ];

# %% [markdown]
# #### Leo los vectores diferencia y los normalizo
# #### Obtengo las proyecciónes de vectores diferencia sobre los 1eros PCA

# %% [raw]
# cuentas = 125
# in_bins = collect(-1:.025:1)
# his_ind_12, his_12 = JUMD.MatHisInd2D(prj_1_4xcp, prj_2_4xcp, in_bins, in_bins);
# his_ind_13, his_13 = JUMD.MatHisInd2D(prj_1_4xcp, prj_3_4xcp, in_bins, in_bins);
# his_ind_23, his_23 = JUMD.MatHisInd2D(prj_2_4xcp, prj_3_4xcp, in_bins, in_bins);
#
# msk_12 = his_12 .> cuentas
# main_his_12 = his_12[msk_12]
# main_his_ind_12 = his_ind_12[msk_12];
#
# msk_13 = his_13 .> cuentas
# main_his_13 = his_13[msk_13]
# main_his_ind_13 = his_ind_13[msk_13];
#
# msk_23 = his_23 .> cuentas
# main_his_23 = his_23[msk_23]
# main_his_ind_23 = his_ind_23[msk_23];
#
# # 1
# spy(msk_12[15:50, 20:32])
# # 2
# spy(msk_12[69:80, 25:55])
# # 3
# spy(msk_12[25:48, 70:80])
#
# idx_vol1 = collect(Iterators.flatten(his_ind_12[15:50, 20:32]))
# idx_vol2 = collect(Iterators.flatten(his_ind_12[69:80, 25:55]))
# idx_vol3 = collect(Iterators.flatten(his_ind_12[25:48, 70:80]));
#
# # Indices de poblaciones
# writedlm(joinpath(rtdos, string(pdb, "_idx_vol1")), idx_vol1)
# writedlm(joinpath(rtdos, string(pdb, "_idx_vol2")), idx_vol2)
# writedlm(joinpath(rtdos, string(pdb, "_idx_vol3")), idx_vol3)

# %% [raw]
# # Preparo
# in_trj = Trajectory(joinpath(home, pdb, "pca", string("full_avgfit_", pdb, ".nc")))
# nframes = convert(Int64, nsteps(in_trj))
# close(in_trj)
#
# # Uso esto p/ dividir las trayectorias a escribir en 10 partes y q
# # no me llenen la memoria
# function filter_trj(indices::Array{Int64, 1},
#     in_filename::AbstractString, ou_filename::AbstractString)
#     # Divide la corrida en 10 secciones
#     idx_ = convert(Int64, ceil(length(indices) / 10))
#     secc = [ collect(1:idx_:length(indices)) ; length(indices) ]
#     secc[end] += 1
#
#     ou_trj = Trajectory(ou_filename, 'w')
#     for j in 1:length(secc) - 1
#         in_trj = Trajectory(in_filename)
#         for i in secc[j]:secc[j+1]-1
#             in_frm = read_step(in_trj, indices[i] - 1)
#             write(ou_trj, in_frm)
#         end
#         close(in_trj)
#         println(j)
#         GC.gc()
#     end
#     close(ou_trj)
# end
#
# filter_trj(idx_vol1, joinpath(home, pdb, "pca", string("full_avgfit_", pdb, ".nc")),
#     joinpath(home, pdb, string("poblaciones/vol1_", pdb, ".nc")))
# filter_trj(idx_vol2, joinpath(home, pdb, "pca", string("full_avgfit_", pdb, ".nc")),
#     joinpath(home, pdb, string("poblaciones/vol2_", pdb, ".nc")))
# filter_trj(idx_vol3, joinpath(home, pdb, "pca", string("full_avgfit_", pdb, ".nc")),
#     joinpath(home, pdb, string("poblaciones/vol3_", pdb, ".nc")))

# %%
idx_vol1 = convert(Array{Int64}, readdlm(joinpath(rtdos, string(pdb, "_idx_vol1")))[:, 1])
idx_vol2 = convert(Array{Int64}, readdlm(joinpath(rtdos, string(pdb, "_idx_vol2")))[:, 1])
idx_vol3 = convert(Array{Int64}, readdlm(joinpath(rtdos, string(pdb, "_idx_vol3")))[:, 1])

# Estiro el volumen 
full_trj_vol = Array{Float64}(undef, length(trj_vol)*10)
for i = 1:length(trj_vol)
    k = (i-1) * 10 + 1
    full_trj_vol[k:k+9] =  fill(trj_vol[i], 10)
end

trj_vol1 = full_trj_vol[idx_vol1]
trj_vol2 = full_trj_vol[idx_vol2]
trj_vol3 = full_trj_vol[idx_vol3];

# %%
st = 40
bw = 28
fa = .7
bin_range = 700:st:2300
bin_vol = collect(bin_range)

# Histograma ponderado
wgh_vol = fill(1.0, length(idx_vol1))
bin_vol1_4xcp, his_vol1_4xcp = JUMD.WeightedHist(trj_vol1, bin_vol, wgh_vol, true, false)

wgh_vol = fill(1.0, length(idx_vol2))
bin_vol2_4xcp, his_vol2_4xcp = JUMD.WeightedHist(trj_vol2, bin_vol, wgh_vol, true, false)

wgh_vol = fill(1.0, length(idx_vol3))
bin_vol3_4xcp, his_vol3_4xcp = JUMD.WeightedHist(trj_vol3, bin_vol, wgh_vol, true, false)

grp = repeat(["pop 1", "pop 2", "pop 3"], inner = length(bin_vol1_4xcp))
clr = repeat([colorant"#3DDAD7", colorant"#2A93D5", colorant"#6d138b"],
    inner = length(bin_vol1_4xcp))

plt_his_vols = groupedbar(
    repeat(bin_vol1_4xcp, outer = 3), hcat(his_vol1_4xcp, his_vol2_4xcp, his_vol3_4xcp),
    group = grp, fillcolor = clr, bar_width = 45,
    xticks = 1E3:250:2E3, yticks = .05:.05:.2,
    xlims = (700, 2300), ylims = (0, .2),
    
    linecolor = false, legend = (.9, .95),
    grid = false, guidefont = font(16, "cursive"), tickfont = font(11, "cursive"),
    yaxis = L"Frequency $[cm^{-1}]$", xaxis = L"Volume $[\AA^3]$ ")

# %% [markdown]
# ## Separo las 3 poblaciones según PCA de ligando

# %% [raw]
# function diff_trj_avg(in_avg_filename::AbstractString, in_trj_filename::AbstractString,
#         mask::Array{Int64, 1})
#     in_avg_trj = Trajectory(in_avg_filename)
#     in_avg_frm = read(in_avg_trj)
#     in_avg_top = Topology(in_avg_frm)
#     orig_aa = convert(Int64, count_residues(in_avg_top))
#
#     # Get indices de CA
#     orig_cas_idx = Array{Int64, 1}(undef, orig_aa)
#     k = 0
#     for i = 0:convert(Int64, size(in_avg_top)-1)
#         if Chemfiles.name(Atom(in_avg_frm, i)) == "CA"
#             k+=1
#             orig_cas_idx[k] = i + 1
#         end
#     end
#     cas_idx = orig_cas_idx[mask]
#     aa = length(cas_idx)
#     aa_3 = aa * 3
#     # Estas son las coordenadas q voy a usar p/ restar
#     avg_xyz = positions(in_avg_frm)[:, cas_idx];
#
#     # Preparo
#     in_trj = Trajectory(in_trj_filename)
#     nframes = convert(Int64, nsteps(in_trj))
#     close(in_trj)
#     diff_pdb = Array{Float64, 2}(undef, aa_3, nframes)
#     st = convert(Int64, floor(nframes/10))
#     chunks = convert(Array{Int64}, collect(0:st:nframes));
#     chunks[end] == nframes || push!(chunks, nframes)
#
#     # Ahora obtengo las proyecciones
#     for j = 1:length(chunks)-1
#         in_trj = Trajectory(in_trj_filename)
#         for i = chunks[j]:chunks[j+1]-1
#             diff_pdb[:, i+1] =
#                 reshape(positions(read_step(in_trj, i))[:, cas_idx] .- avg_xyz, aa_3)
#         end
#         close(in_trj)
#         println(j)
#         GC.gc()
#     end
#
#     return diff_pdb
# end
# # 1
# dif_vol1 = diff_trj_avg(joinpath(home, pdb, "poblaciones", "pca", "1",
#     string("vol1_avg_", pdb, ".pdb")),
#     joinpath(home, pdb, "poblaciones", "pca", "1", string("vol1_avgfit_", pdb, ".nc")),
#     collect(10:144))
#
# fid = h5open(joinpath(rtdos, string("diff_vol1", pdb, ".h5")), "w")
# write(fid, "dif",dif_vol1)
# close(fid)
#
# # 2smooth_prj_2_4xcp_vol1
# dif_vol2 = diff_trj_avg(joinpath(home, pdb, "poblaciones", "pca", "2",
#     string("vol2_avg_", pdb, ".pdb")),
#     joinpath(home, pdb, "poblaciones", "pca", "2", string("vol2_avgfit_", pdb, ".nc")),
#     collect(10:144))
#
# fid = h5open(joinpath(rtdos, string("diff_vol2", pdb, ".h5")), "w")
# write(fid, "dif",dif_vol2)
# close(fid)
#
# # 3
# dif_vol3 = diff_trj_avg(joinpath(home, pdb, "poblaciones", "pca", "3",
#     string("vol3_avg_", pdb, ".pdb")),
#     joinpath(home, pdb, "poblaciones", "pca", "3", string("vol3_avgfit_", pdb, ".nc")),
#     collect(10:144))
#
# fid = h5open(joinpath(rtdos, string("diff_vol3", pdb, ".h5")), "w")
# write(fid, "dif",dif_vol3)
# close(fid)

# %%
dif_vol1 = h5read(joinpath(rtdos, string("diff_vol1", pdb, ".h5")), "dif")
norm_dif_vol1 = mapslices(x -> x ./ norm(x), dif_vol1,  dims = 1)
nframes_vol1 = size(dif_vol1)[2]

# Leo modos
modes_4xcp_vol1, evals_4xcp_vol1 = JUMD.readPtrajModes(
    joinpath(home, pdb, "poblaciones", "pca", "1", string("1vol_modes_", pdb)))

prj_1_4xcp_vol1 = Array{Float64, 1}(undef, nframes_vol1)
prj_2_4xcp_vol1 = Array{Float64, 1}(undef, nframes_vol1)
prj_3_4xcp_vol1 = Array{Float64, 1}(undef, nframes_vol1)

for i = 1:nframes_vol1
    prj_1_4xcp_vol1[i] = dot(norm_dif_vol1[:, i], modes_4xcp_vol1[:, 1])
    prj_2_4xcp_vol1[i] = dot(norm_dif_vol1[:, i], modes_4xcp_vol1[:, 2])
    prj_3_4xcp_vol1[i] = dot(norm_dif_vol1[:, i], modes_4xcp_vol1[:, 3])
end

# Smooth
smooth_prj_1_4xcp_vol1 = JUMD.suave(prj_1_4xcp_vol1, 10)
smooth_prj_2_4xcp_vol1 = JUMD.suave(prj_2_4xcp_vol1, 10)
smooth_prj_3_4xcp_vol1 = JUMD.suave(prj_3_4xcp_vol1, 10);

# %%
dif_vol2 = h5read(joinpath(rtdos, string("diff_vol2", pdb, ".h5")), "dif")
norm_dif_vol2 = mapslices(x -> x ./ norm(x), dif_vol2,  dims = 1)
nframes_vol2 = size(dif_vol2)[2]

# Leo modos
modes_4xcp_vol2, evals_4xcp_vol2 = JUMD.readPtrajModes(
    joinpath(home, pdb, "poblaciones", "pca", "2", string("2vol_modes_", pdb)))

prj_1_4xcp_vol2 = Array{Float64, 1}(undef, nframes_vol2)
prj_2_4xcp_vol2 = Array{Float64, 1}(undef, nframes_vol2)
prj_3_4xcp_vol2 = Array{Float64, 1}(undef, nframes_vol2)

for i = 1:nframes_vol2
    prj_1_4xcp_vol2[i] = dot(norm_dif_vol2[:, i], modes_4xcp_vol2[:, 1])
    prj_2_4xcp_vol2[i] = dot(norm_dif_vol2[:, i], modes_4xcp_vol2[:, 2])
    prj_3_4xcp_vol2[i] = dot(norm_dif_vol2[:, i], modes_4xcp_vol2[:, 3])
end

# Smooth
smooth_prj_1_4xcp_vol2 = JUMD.suave(prj_1_4xcp_vol2, 10)
smooth_prj_2_4xcp_vol2 = JUMD.suave(prj_2_4xcp_vol2, 10)
smooth_prj_3_4xcp_vol2 = JUMD.suave(prj_3_4xcp_vol2, 10);

# %%
dif_vol3 = h5read(joinpath(rtdos, string("diff_vol3", pdb, ".h5")), "dif")
norm_dif_vol3 = mapslices(x -> x ./ norm(x), dif_vol3,  dims = 1)
nframes_vol3 = size(dif_vol3)[2]

# Leo modos
modes_4xcp_vol3, evals_4xcp_vol3 = JUMD.readPtrajModes(
    joinpath(home, pdb, "poblaciones", "pca", "3", string("3vol_modes_", pdb)))

prj_1_4xcp_vol3 = Array{Float64, 1}(undef, nframes_vol3)
prj_2_4xcp_vol3 = Array{Float64, 1}(undef, nframes_vol3)
prj_3_4xcp_vol3 = Array{Float64, 1}(undef, nframes_vol3)

for i = 1:nframes_vol3
    prj_1_4xcp_vol3[i] = dot(norm_dif_vol3[:, i], modes_4xcp_vol3[:, 1])
    prj_2_4xcp_vol3[i] = dot(norm_dif_vol3[:, i], modes_4xcp_vol3[:, 2])
    prj_3_4xcp_vol3[i] = dot(norm_dif_vol3[:, i], modes_4xcp_vol3[:, 3])
end

# Smooth
smooth_prj_1_4xcp_vol3 = JUMD.suave(prj_1_4xcp_vol3, 10)
smooth_prj_2_4xcp_vol3 = JUMD.suave(prj_2_4xcp_vol3, 10)
smooth_prj_3_4xcp_vol3 = JUMD.suave(prj_3_4xcp_vol3, 10);

# %%
plt_2his = Plots.histogram2d(smooth_prj_1_4xcp_vol1, smooth_prj_2_4xcp_vol1,
    xlims = (-1., 1.), ylims = (-1., 1.),
    guidefont = font(16, "Helvetica"), tickfont = font(11, "Helvetica"),
    yaxis = "PCA 2", xaxis = "PCA 1",
    colorbar_title = "Frame count",
    nbins = 180, seriescolor = :amp, grid = false)

# %%
plt_2his = Plots.histogram2d(smooth_prj_1_4xcp_vol2, smooth_prj_2_4xcp_vol2,
    xlims = (-1., 1.), ylims = (-1., 1.),
    guidefont = font(16, "Helvetica"), tickfont = font(11, "Helvetica"),
    yaxis = "PCA 2", xaxis = "PCA 1",
    colorbar_title = "Frame count",
    nbins = 180, seriescolor = :amp, grid = false)

# %%
plt_2his = Plots.histogram2d(smooth_prj_1_4xcp_vol3, smooth_prj_2_4xcp_vol3,
    xlims = (-1., 1.), ylims = (-1., 1.),
    guidefont = font(16, "Helvetica"), tickfont = font(11, "Helvetica"),
    yaxis = "PCA 2", xaxis = "PCA 1",
    colorbar_title = "Frame count",
    nbins = 180, seriescolor = :amp, grid = false)

# %%
vol1_avgfit_4xcp.nc.nc
vol1_avg_4xcp.pdb
